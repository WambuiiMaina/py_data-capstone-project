# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Screening by region
# What is the prevalence of cervical cancer and where are the regional hotspots

# %%
screening_rate_by_region = pd.read_csv('Prevalence_by_region.csv')
screening_rate_by_region
# Out:
#           Region  Screened   Total  Prevalence  Lower_CI  Upper_CI  Weight
# 0          Coast     182.0  2105.0        8.65      7.45      9.85   10.00
# 1  North Eastern      11.0  1202.0        0.92      0.38      1.45   49.73
# 2        Eastern     306.0  2601.0       11.76     10.53     13.00    9.40
# 3        Central     372.0  1556.0       23.91     21.79     26.03    3.21
# 4    Rift Valley     707.0  5083.0       13.91     12.96     14.86   15.92
# 5        Western     207.0  1637.0       12.65     11.04     14.26    5.56
# 6        Nairobi     566.0  2717.0       20.83     19.30     22.36    6.18
# 7         Pooled       NaN     NaN        7.40      7.02      7.78  100.00

# %%
screening_rate_by_region.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      8 non-null      str
#  1   Screened    7 non-null      float64
#  2   Total       7 non-null      float64
#  3   Prevalence  8 non-null      float64
#  4   Lower_CI    8 non-null      float64
#  5   Upper_CI    8 non-null      float64
#  6   Weight      8 non-null      float64
# dtypes: float64(6), str(1)
# memory usage: 580.0 bytes

# %%
screening_rate = screening_rate_by_region['Screening_Rate'].mean()
screening_rate
# Out:
# np.float64(12.50375)

# %%
plt.barh(screening_rate_by_region['Region'], screening_rate_by_region['Prevalence'])

plt.title('Screening Rate of Cervical Cancer by Region')
plt.xlabel('Screening Rate (%)')
plt.ylabel('Region')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Prevalence by sociodemographic factors eg age, marital status,education, SES etc
#
# Defining who is being screened and who is not and exposing the gaps that can be addressed

# %%
sociodemographic_factors = pd.read_csv('Sociodemographic_data.csv')
sociodemographic_factors
# Out:
#              Category                       Group  Weighted_Frequency  \
# 0                 Age                       15-19                3125
# 1                 Age                       20-24                3063
# 2                 Age                       25-29                2916
# 3                 Age                       30-34                2364
# 4                 Age                       35-39                2288
# 5                 Age                       40-44                1614
# 6                 Age                       45-49                1346
# 7      Marital Status                      Single                5348
# 8      Marital Status                     Married                9319
# 9      Marital Status  Divorced/Widowed/Separated                2049
# 10          Education         No formal education                 920
# 11          Education                     Primary                6107
# ...

# %%
sociodemographic_factors.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Category            30 non-null     str
#  1   Group               30 non-null     str
#  2   Weighted_Frequency  30 non-null     int64
#  3   No_Count            30 non-null     int64
#  4   No_Percent          30 non-null     float64
#  5   Yes_Count           30 non-null     int64
#  6   Yes_Percent         30 non-null     float64
# dtypes: float64(2), int64(3), str(2)
# memory usage: 1.8 KB

# %% [markdown]
# #### Screening trend by age
# Insights- it increases with age

# %%
age = sociodemographic_factors[
    sociodemographic_factors['Category'] == 'Age'
]

plt.plot(age['Group'], age['Yes_Percent'], marker='v', linestyle='-', color='green')

plt.title("Trend of Screening Across Age Groups")
plt.xlabel("Age Group")
plt.ylabel("Screening Rate (%)")

plt.xticks(ticks=range(len(age['Group'])), labels=age['Group'])

plt.grid(False)
plt.show()

# %% [markdown]
# #### Marital status

# %%
marital_data = sociodemographic_factors[
    sociodemographic_factors['Category'] == 'Marital Status'
]

Fig, ax = plt.subplots()
ax.bar(marital_data['Group'], marital_data['Yes_Percent'], color=['skyblue', 'orange', 'green'])

plt.title("Screening Rate by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Screening Rate (%)")

plt.tight_layout()

plt.show()

# %% [markdown]
# #### Education level

# %%
edu_data = sociodemographic_factors[
    sociodemographic_factors['Category'] == 'Education'
]

Fig, ax = plt.subplots()
ax.bar(edu_data['Group'], edu_data['Yes_Percent'], 
       color=['cyan',
              'teal',
              'pink',
              'purple'])

plt.title("Screening Rate by Education Level")

plt.xlabel("Education Level")
plt.ylabel("Screening Rate (%)")

plt.show()

# %% [markdown]
# #### Empolyment status

# %%
employment_data = sociodemographic_factors[
    sociodemographic_factors['Category'] == 'Employment Status'
]

plt.pie(employment_data['Yes_Percent'], labels=employment_data['Group'], autopct='%1.1f%%', startangle=140)

plt.title("Screening Rate by Employment Status")

plt.show()

# %% [markdown]
# #### Wealth index

# %%
wealth_data = sociodemographic_factors[
    sociodemographic_factors['Category'] == 'Wealth Index'
]
Fig, ax = plt.subplots()
ax.bar(wealth_data['Group'], wealth_data['Yes_Percent'], color=['lightcoral', 'lightseagreen', 'lightsteelblue', ])

plt.title("Screening Rate by Wealth Index")

plt.xlabel("Wealth Category")
plt.ylabel("Screening Rate (%)")
plt.show()

# %% [markdown]
# #### Residence pattern

# %%
residence_data = sociodemographic_factors[
    sociodemographic_factors['Category'] == 'Residence'
]

plt.pie(residence_data['Yes_Percent'], labels=residence_data['Group'], autopct='%1.1f%%', startangle=140)

plt.title("Screening Rate by Residence")
plt.legend(title='Residence Type', labels=['Urban', 'Rural'])

plt.show()

# %% [markdown]
# #### Media exposure

# %%
media_data = sociodemographic_factors[
    sociodemographic_factors['Category'] == 'Media Exposure'
]

plt.pie(media_data['Yes_Percent'], labels=media_data['Group'], autopct='%1.1f%%', startangle=140)

plt.title("Screening Rate by Media Exposure")

plt.show()

# %% [markdown]
# #### Summary of all the sociodemographic factors

# %%
pivot = sociodemographic_factors.pivot(
    index='Category',
    columns='Group',
    values='Yes_Percent'
)

plt.figure(figsize=(12, 6))  # 👈 makes it bigger

sns.heatmap(
    pivot,
    annot=True,
    cmap='coolwarm',
    fmt=".1f",
    linewidths=0.5,
    cbar_kws={'label': 'Screening Rate (%)'}
)

plt.title("Cervical Cancer Screening Rates by Category and Group", fontsize=14)
plt.xlabel("Group")
plt.ylabel("Category")

plt.xticks(rotation=90)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()
